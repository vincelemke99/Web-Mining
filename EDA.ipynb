# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
df_reviews = pd.read_csv(r"../All-XWines_Full_100K_wines_21M_ratings/XWines_Full_21M_ratings.csv")
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_10388\4166625741.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_reviews = pd.read_csv(r"../All-XWines_Full_100K_wines_21M_ratings/XWines_Full_21M_ratings.csv")

# %%
# replace N.V. non-vintage with 0 to make it a categorical int
df_reviews["Vintage"] = df_reviews["Vintage"].replace("N.V.", 0)

# %%
reviews_type_schema = {"UserID": "categorical", "WineID": "categorical", "Vintage": "categorical"}
df_reviews_profile = ProfileReport(df_reviews, title="XWines Review Report")
df_reviews_profile.to_file("xwines_review_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#  17%|█████████████▊                                                                     | 1/6 [01:55<09:35, 115.08s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [04:20<00:00, 43.47s/it]
# C:\Users\frede\Documents\Uni_Mannheim\Master\03_Semester\Web Mining Project\xwines_recom\.venv\Lib\site-packages\matplotlib\image.py:183: UserWarning: Data with more than 2**24 rows cannot be accurately displayed. Downsampling to less than 2**24 rows before displaying. To remove this warning, manually downsample your data.
#   warnings.warn(msg.format(n='2**24 rows'))
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_reviews.groupby("WineID").RatingID.count().sort_values(ascending=False)
# Out:
# WineID
# 155289    27415
# 179010    23626
# 179011    21216
# 111391    20913
# 167418    20817
#           ...
# 200714        5
# 200713        5
# 200712        5
# 200711        5
# 200710        5
# Name: RatingID, Length: 100646, dtype: int64

# %%
df_reviews.groupby("WineID").RatingID.count().sort_values(ascending=False).describe()
# Out:
# count    100646.000000
# mean        208.786599
# std         588.611438
# min           5.000000
# 25%          22.000000
# 50%          58.000000
# 75%         187.000000
# max       27415.000000
# Name: RatingID, dtype: float64

# %% [markdown]
# count    100646.000000
#
# mean        208.786599
#
# std         588.611438
#
# min           5.000000
#
# 25%          22.000000
#
# 50%          58.000000
#
# 75%         187.000000
#
# max       27415.000000
# Name: RatingID, dtype: float64
#
# ![grafik.png](attachment:e5fe1c1f-61de-4e6f-afb4-72b9d5eba8d3.png)

# %% [markdown]
# #### User

# %%
df_reviews.groupby("UserID").RatingID.count().describe()
# Out:
# count    1.056079e+06
# mean     1.989769e+01
# std      4.035217e+01
# min      5.000000e+00
# 25%      8.000000e+00
# 50%      1.100000e+01
# 75%      2.000000e+01
# max      2.986000e+03
# Name: RatingID, dtype: float64

# %% [markdown]
# The results
#
# ![grafik.png](attachment:d601ff24-2931-4974-91a2-5dea6df1f7ff.png)

# %%
df_reviews.groupby("UserID").RatingID.count().sort_values(ascending=False)
# Out:
# UserID
# 1084433    2986
# 1034989    2979
# 1070878    2613
# 1048267    2597
# 1160536    2392
#            ...
# 2063387       5
# 2063348       5
# 2063337       5
# 2063354       5
# 2063381       5
# Name: RatingID, Length: 1056079, dtype: int64

# %% [markdown]
# ### Relations on the frequency between users and wines

# %%
user_wine_rating_occurences = df_reviews[["UserID", "WineID"]].value_counts()
user_wine_rating_occurences
# Out:
# UserID   WineID
# 1174177  156461    23
# 1127980  142757    22
# 2043942  120830    20
# 1394272  155345    19
# 2036081  179070    19
#                    ..
# 2063390  179015     1
#          179063     1
#          179081     1
#          179396     1
#          188991     1
# Name: count, Length: 20590800, dtype: int64

# %%
df_reviews.loc[df_reviews.UserID==1174177]
# Out:
#           RatingID   UserID  WineID Vintage  Rating                 Date
# 93252        93253  1174177  155515    1986     4.5  2016-06-20 12:56:12
# 156115      156116  1174177  155303    1992     4.0  2016-04-24 13:03:38
# 353431      353432  1174177  156461    1999     5.0  2021-02-06 13:05:50
# 554168      554169  1174177  156461    2002     5.0  2021-06-07 09:24:30
# 599564      599565  1174177  156461    2003     5.0  2019-06-25 08:01:13
# 627598      627599  1174177  156461    2003     5.0  2018-11-24 13:28:37
# 643031      643032  1174177  155290    2004     5.0  2020-10-21 07:29:32
# 690061      690062  1174177  155290    2004     5.0  2020-02-02 10:11:48
# 763400      763401  1174177  156461    2005     5.0  2020-10-16 09:27:24
# 845036      845037  1174177  111436    2005     5.0  2020-12-28 14:09:58
# 881778      881779  1174177  155312    2005     5.0  2020-09-14 16:17:45
# 941513      941514  1174177  156461    2006     5.0  2019-11-04 11:07:01
# 1018515    1018516  1174177  156575    2006     5.0  2020-02-09 15:31:13
# 1074921    1074922  1174177  155312    2006     5.0  2018-12-29 06:48:34
# 1210833    1210834  1174177  157442    2007     5.0  2018-12-29 06:50:40
# 1210886    1210887  1174177  156461    2007     5.0  2018-12-29 06:47:26
# 1210961    1210962  1174177  157442    2007     5.0  2020-11-14 08:56:02
# 1222109    1222110  1174177  157442    2007     5.0  2020-11-01 14:03:59
# 1428881    1428882  1174177  156461    2008     5.0  2020-06-08 06:45:11
# 1446897    1446898  1174177  157442    2008     5.0  2020-12-03 18:48:23
# 1504920    1504921  1174177  157442    2008     5.0  2020-05-27 11:36:31
# 1611077    1611078  1174177  156461    2008     5.0  2019-05-13 19:57:39
# 1722450    1722451  1174177  156461    2008     5.0  2020-04-11 09:43:43
# 1722453    1722454  1174177  157442    2008     5.0  2020-04-11 09:48:26
# 1775838    1775839  1174177  156461    2008     5.0  2020-10-21 07:32:44
# 1799082    1799083  1174177  155312    2008     5.0  2019-01-02 19:43:18
# 1800188    1800189  1174177  156461    2008     5.0  2020-09-14 16:15:06
# 1996152    1996153  1174177  156461    2009     5.0  2021-02-04 07:54:26
# 2091333    2091334  1174177  156461    2009     5.0  2018-11-01 14:25:52
# 2334744    2334745  1174177  156461    2009     5.0  2020-10-24 14:15:14
# 2353099    2353100  1174177  156461    2009     5.0  2020-12-08 22:06:05
# 2648252    2648253  1174177  156461    2010     5.0  2020-06-24 12:47:26
# 2896771    2896772  1174177  156461    2010     5.0  2020-10-16 09:26:51
# 2962381    2962382  1174177  155312    2010     5.0  2020-12-29 08:32:22
# 3279868    3279869  1174177  157442    2010     5.0  2021-04-26 14:55:06
# 4080672    4080673  1174177  156461    2011     5.0  2020-01-15 12:57:14
# 4090863    4090864  1174177  156461    2011     5.0  2021-03-08 14:34:31
# 4163481    4163482  1174177  156461    2011     5.0  2020-05-19 15:35:42
# 4189684    4189685  1174177  162497    2011     4.0  2016-10-24 09:30:45
# 4513312    4513313  1174177  155290    2012     5.0  2018-11-25 13:35:38
# 7231435    7231436  1174177  156461    2013     5.0  2019-01-21 13:33:49
# 7259481    7259482  1174177  156461    2013     5.0  2019-01-06 14:11:11
# 9771878    9771879  1174177  156028    2015     5.0  2018-10-23 19:03:58
# 11683737  11683738  1174177  156123    2015     5.0  2019-06-16 18:37:09
# 11797674  11797675  1174177  156123    2015     5.0  2020-05-19 15:36:12
# 14068241  14068242  1174177  155486    2016     5.0  2018-11-04 14:33:13
# 14953965  14953966  1174177  159042    2017     5.0  2021-04-26 14:57:52
# 15468807  15468808  1174177  159042    2017     5.0  2020-08-02 07:42:37
# 17407790  17407791  1174177  159042    2018     5.0  2021-06-07 09:21:19
